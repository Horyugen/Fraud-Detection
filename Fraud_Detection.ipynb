# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('train_transaction.csv')
df2=pd.read_csv('train_identity.csv')
df=pd.merge(df1,df2)

# %%
fraud = df.loc[df['isFraud'] == 1]
non_fraud = df.loc[df['isFraud'] == 0]
print(len(fraud))
print(len(non_fraud))

ax = fraud.plot.scatter(x='TransactionAmt', y='isFraud', color='Orange', label='Fraud')
non_fraud.plot.scatter(x='TransactionAmt', y='isFraud', color='Blue', label='Normal', ax=ax)
plt.show()
# Out:
# 710
# 16981

# %%
numeric_features=['card1']+['card2']+['card3']+['card5']+['addr%d' % number for number in range(1,3)]
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_features=['ProductCD']+['P_emaildomain']+['R_emaildomain']+['card4']+['card6']+['M%d' % number for number in range(1,10)]+['DeviceType']+['DeviceInfo']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])
target='isFraud'
X=df.drop('isFraud',axis=1)
y=df['isFraud']

# %%
# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(solver='lbfgs'))])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_test, y_test))
# Out:
# model score: 0.961
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
df
# Out:
#        TransactionID  isFraud  ...  DeviceType                      DeviceInfo
# 0            2987004        0  ...      mobile   SAMSUNG SM-G892A Build/NRD90M
# 1            2987008        0  ...      mobile                      iOS Device
# 2            2987010        0  ...     desktop                         Windows
# 3            2987011        0  ...     desktop                             NaN
# 4            2987016        0  ...     desktop                           MacOS
# 5            2987017        0  ...     desktop                         Windows
# 6            2987022        0  ...         NaN                             NaN
# 7            2987038        0  ...      mobile                             NaN
# 8            2987040        0  ...     desktop                         Windows
# 9            2987048        0  ...     desktop                         Windows
# 10           2987049        0  ...     desktop                         Windows
# 11           2987057        0  ...      mobile           SM-G930V Build/NRD90M
# 12           2987066        0  ...     desktop                         Windows
# 13           2987069        0  ...     desktop                             NaN
# 14           2987070        0  ...      mobile                      iOS Device
# 15           2987072        0  ...      mobile         BLADE A602 Build/MRA58K
# 16           2987074        0  ...     desktop                         Windows
# 17           2987084        0  ...     desktop                         Windows
# 18           2987093        0  ...     desktop                         Windows
# 19           2987099        0  ...      mobile                      iOS Device
# 20           2987100        0  ...      mobile           SM-G930V Build/NRD90M
# 21           2987101        0  ...     desktop                           MacOS
# 22           2987104        0  ...      mobile           SM-G930V Build/NRD90M
# 23           2987105        0  ...      mobile  XT1635-02 Build/NPN26.118-22-2
# 24           2987108        0  ...         NaN                             NaN
# 25           2987111        0  ...     desktop                         Windows
# 26           2987114        0  ...     desktop                         Windows
# 27           2987119        0  ...     desktop                           MacOS
# 28           2987121        0  ...     desktop                           MacOS
# 29           2987125        0  ...     desktop                           MacOS
# ...              ...      ...  ...         ...                             ...
# 17661        3039920        0  ...     desktop                         Windows
# 17662        3039923        0  ...     desktop                     Trident/7.0
# 17663        3039936        0  ...     desktop                         rv:11.0
# 17664        3039938        0  ...     desktop                         Windows
# 17665        3039939        0  ...     desktop                           MacOS
# 17666        3039941        0  ...      mobile                      iOS Device
# 17667        3039952        0  ...      mobile               Z983 Build/NMF26F
# 17668        3039953        0  ...     desktop                         rv:52.0
# 17669        3039954        0  ...      mobile               Z983 Build/NMF26F
# 17670        3039959        0  ...     desktop                         Windows
# 17671        3039961        0  ...      mobile                      iOS Device
# 17672        3039963        0  ...     desktop                         Windows
# 17673        3039968        0  ...      mobile     Pixel Build/OPM1.171019.011
# 17674        3039972        0  ...     desktop                         rv:11.0
# 17675        3039973        0  ...     desktop                         rv:11.0
# 17676        3039974        0  ...     desktop                           MacOS
# 17677        3039977        0  ...      mobile                      iOS Device
# 17678        3039980        0  ...     desktop                         Windows
# 17679        3039981        0  ...     desktop                     Trident/7.0
# 17680        3039983        0  ...     desktop                           MacOS
# 17681        3039984        0  ...     desktop                         Windows
# 17682        3039987        0  ...     desktop                         Windows
# 17683        3039989        0  ...     desktop                         Windows
# 17684        3039994        0  ...     desktop                     Trident/7.0
# 17685        3039995        0  ...      mobile                      iOS Device
# 17686        3039996        0  ...     desktop                         Windows
# 17687        3040000        0  ...         NaN                             NaN
# 17688        3040001        0  ...     desktop                           MacOS
# 17689        3040002        0  ...     desktop                         Windows
# 17690        3040004        0  ...      mobile   SAMSUNG SM-G955U Build/NRD90M
#
# [17691 rows x 434 columns]
